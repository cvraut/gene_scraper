# %% [markdown]
# # Gene card scraper

# %% [markdown]
# this notebook loads the data from the `data/gene_list/genes.list` file.
#
# and scrapes Gene cards database specifically trying to grab the data located in the `https://www.genecards.org/cgi-bin/carddisp.pl?gene=${GENE}`

# %%
# options
sub_seperator = ","

# load list of genes
gene_rows = []
with open("../../data/gene_list/genes.list","r") as f:
  gene_rows = [line.strip() for line in f.readlines()]

gene_set = set()
genes = []
for g in gene_rows:
  for sg in g.split(sub_seperator):
    if sg not in gene_set:
      gene_set.add(sg)
      genes.append(sg)

print("{} genes loaded".format(len(genes)))
# Out:
# 150 genes loaded

# %%
genes[:5]
# Out:
# ['CFAP74', 'PRDM16-DT', 'AGMAT', 'MACF1', 'NFIA']

# %%
# load the libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
import random
import regex as re

# %%
selected_gene = genes[0]
genecard_url = 'https://www.genecards.org/cgi-bin/carddisp.pl?gene={}'

selected_url = genecard_url.format(selected_gene)

payload={}

UAS = ("Mozilla/5.0 (Windows NT 6.1; WOW64; rv:40.0) Gecko/20100101 Firefox/40.1", 
       "Mozilla/5.0 (Windows NT 6.3; rv:36.0) Gecko/20100101 Firefox/36.0",
       "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; rv:33.0) Gecko/20100101 Firefox/33.0",
       "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36",
       "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36",
       "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36",
       )

ua = UAS[random.randrange(len(UAS))]
headers = {
  'user-agent':ua
}

response = requests.request("GET", selected_url, headers=headers, data=payload)

#print(response.text)

soup = BeautifulSoup(response.text, 'html.parser')
all_divs = soup.findAll("section",id="summaries")
print(len(all_divs))
#sub_soup = BeautifulSoup(all_divs[0],"html.parser")
all_subsections = all_divs[0].findAll("div",class_="gc-subsection")
print(len(all_subsections))
print(all_subsections[0])

h1 = soup.findAll("h1",id="geneSymbol")
if h1 and h1[0]:
  print(h1[0].findAll("small"))
# Out:
# 1
# 5
# <div class="gc-subsection">
# <div class="gc-subsection-header">
# <h3>Entrez Gene Summary for CFAP74 Gene</h3>
# <a class="gc-ga-link glyphicon glyphicon-new-window" data-ga-action="ENT" data-ga-source-accession="85452" href="https://www.ncbi.nlm.nih.gov/gene/85452#summary" target="_blank" title="See NCBI Entrez Gene entry for CFAP74"></a>
# </div>
# <ul class="list-unstyled">
# <li>
# <p>Predicted to be involved in axoneme assembly. Predicted to be located in axoneme. [provided by Alliance of Genome Resources, Apr 2022]</p>
# </li>
# </ul>
# </div>
# [<small>
#                     Gene
#                         <span id="geneDescription" title="Cilia And Flagella Associated Protein 74">- Cilia And Flagella Associated Protein 74</span>
# </small>]

# %%
def clean_html(html):
    """
    Remove HTML markup from the given string.
    :param html: the HTML string to be cleaned
    :type html: str
    :rtype: str
    """

    # First we remove inline JavaScript/CSS:
    cleaned = re.sub(r"(?is)<(script|style).*?>.*?(</\1>)", "", html.strip())
    # Then we remove html comments. This has to be done before removing regular
    # tags since comments can contain '>' characters.
    cleaned = re.sub(r"(?s)<!--(.*?)-->[\n]?", "", cleaned)
    # Next we can remove the remaining tags:
    cleaned = re.sub(r"(?s)<.*?>", " ", cleaned)
    # Finally, we deal with whitespace
    cleaned = re.sub(r"&nbsp;", " ", cleaned)
    cleaned = re.sub(r"  ", " ", cleaned)
    cleaned = re.sub(r"  ", " ", cleaned)
    return cleaned.strip()

# %%
entry = {}

for subsection in all_subsections:
  header = subsection.findAll("div",class_="gc-subsection-header")
  if header:
    #print(html2text.html2text(str(header[0])))
    header_txt = clean_html(BeautifulSoup.get_text(header[0]))
    if "Summary" in header_txt:
      summary_index = header_txt.index("Summary")
      #print("end header")
      summary_txt = subsection.findAll('p')
      if not summary_txt:
        li_section = subsection.findAll('li')
        if li_section:
          summary_txt = li_section[0].findAll("div")
      if summary_txt:
        entry[header_txt[:summary_index].strip()]=clean_html(BeautifulSoup.get_text(summary_txt[0])).strip()
      #print("end section")

entry
# Out:
# {'Entrez Gene': 'Predicted to be involved in axoneme assembly. Predicted to be located in axoneme. [provided by Alliance of Genome Resources, Apr 2022]',
#  'GeneCards': 'CFAP74 (Cilia And Flagella Associated Protein 74) is a Protein Coding gene.\r\n           Diseases associated with CFAP74 include Familial Cold Autoinflammatory Syndrome 2 and Chromosome 1P36 Deletion Syndrome.',
#  'UniProtKB/Swiss-Prot': 'As part of the central apparatus of the cilium axoneme may play a role in cilium movement.\r\n      \nCFA74_HUMAN,Q9C0B2'}

# %%
def get_entry(gene):
  genecard_url = 'https://www.genecards.org/cgi-bin/carddisp.pl?gene={}'
  selected_url = genecard_url.format(gene)

  payload={}
  UAS = ("Mozilla/5.0 (Windows NT 6.1; WOW64; rv:40.0) Gecko/20100101 Firefox/40.1", 
        "Mozilla/5.0 (Windows NT 6.3; rv:36.0) Gecko/20100101 Firefox/36.0",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; rv:33.0) Gecko/20100101 Firefox/33.0",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36",
        )
  ua = UAS[random.randrange(len(UAS))]
  headers = {
    'user-agent':ua
  }
  response = requests.request("GET", selected_url, headers=headers, data=payload)

  soup = BeautifulSoup(response.text, 'html.parser')
  all_divs = soup.findAll("section",id="summaries")
  all_subsections = all_divs[0].findAll("div",class_="gc-subsection")
  
  entry = {}
  h1 = soup.findAll("h1",id="geneSymbol")
  if h1 and h1[0]:
    small = h1[0].findAll("small")
    if small and small[0]:
      entry["Description"] = " ".join(clean_html(BeautifulSoup.get_text(small[0])).split())

  for subsection in all_subsections:
    header = subsection.findAll("div",class_="gc-subsection-header")
    if header:
      #print(html2text.html2text(str(header[0])))
      header_txt = clean_html(BeautifulSoup.get_text(header[0]))
      if "Summary" in header_txt:
        summary_index = header_txt.index("Summary")
        #print("end header")
        summary_txt = subsection.findAll('p')
        if not summary_txt:
          li_section = subsection.findAll('li')
          if li_section:
            summary_txt = li_section[0].findAll("div")
        if summary_txt:
          entry[header_txt[:summary_index].strip()]=" ".join(clean_html(BeautifulSoup.get_text(summary_txt[0])).strip().split())
        #print("end section")

  return entry

# %%
get_entry(genes[0])
# Out:
# {'Description': 'Gene - Cilia And Flagella Associated Protein 74',
#  'Entrez Gene': 'Predicted to be involved in axoneme assembly. Predicted to be located in axoneme. [provided by Alliance of Genome Resources, Apr 2022]',
#  'GeneCards': 'CFAP74 (Cilia And Flagella Associated Protein 74) is a Protein Coding gene. Diseases associated with CFAP74 include Familial Cold Autoinflammatory Syndrome 2 and Chromosome 1P36 Deletion Syndrome.',
#  'UniProtKB/Swiss-Prot': 'As part of the central apparatus of the cilium axoneme may play a role in cilium movement. CFA74_HUMAN,Q9C0B2'}

# %%
summaries = {}
for i,g in enumerate(genes):
  try:
    summaries[g] = get_entry(g)
  except Exception as e:
    print("Problem with: {}".format(g))
  if i%10 == 0:
    print("Done with {}/{}".format(i,len(genes)))
print(len(summaries))
# Out:
# Done with 0/150
# Done with 10/150
# Done with 20/150
# Done with 30/150
# Done with 40/150
# Done with 50/150
# Done with 60/150
# Done with 70/150
# Done with 80/150
# Done with 90/150
# Done with 100/150
# Problem with: ENSG00000259450
# Done with 110/150
# Done with 120/150
# Done with 130/150
# Done with 140/150
# 149

# %%
summary_data = pd.DataFrame(summaries).transpose()

# %%
summary_data.shape
# Out:
# (149, 6)

# %%
summary_data
# Out:
#                                                  Description  \
# CFAP74       Gene - Cilia And Flagella Associated Protein 74
# PRDM16-DT                 Gene - PRDM16 Divergent Transcript
# AGMAT                                      Gene - Agmatinase
# MACF1         Gene - Microtubule Actin Crosslinking Factor 1
# NFIA                               Gene - Nuclear Factor I A
# ...                                                      ...
# TOP1                              Gene - DNA Topoisomerase I
# EYA2       Gene - EYA Transcriptional Coactivator And Pho...
# TSHZ2                 Gene - Teashirt Zinc Finger Homeobox 2
# BMP7                     Gene - Bone Morphogenetic Protein 7
# MAFF                  Gene - MAF BZIP Transcription Factor F
#
#                                                  Entrez Gene  \
# CFAP74     Predicted to be involved in axoneme assembly. ...
# PRDM16-DT                                                NaN
# AGMAT      Predicted to enable agmatinase activity. Predi...
# MACF1      This gene encodes a large protein containing n...
# NFIA       This gene encodes a member of the NF1 (nuclear...
# ...                                                      ...
# TOP1       This gene encodes a DNA topoisomerase, an enzy...
# EYA2       This gene encodes a member of the eyes absent ...
# TSHZ2      This gene is a member of the teashirt C2H2-typ...
# BMP7       This gene encodes a secreted ligand of the TGF...
# MAFF       The protein encoded by this gene is a basic le...
#
#                                                    GeneCards  \
# CFAP74     CFAP74 (Cilia And Flagella Associated Protein ...
# PRDM16-DT  PRDM16-DT (PRDM16 Divergent Transcript) is an ...
# AGMAT      AGMAT (Agmatinase) is a Protein Coding gene. D...
# MACF1      MACF1 (Microtubule Actin Crosslinking Factor 1...
# NFIA       NFIA (Nuclear Factor I A) is a Protein Coding ...
# ...                                                      ...
# TOP1       TOP1 (DNA Topoisomerase I) is a Protein Coding...
# EYA2       EYA2 (EYA Transcriptional Coactivator And Phos...
# TSHZ2      TSHZ2 (Teashirt Zinc Finger Homeobox 2) is a P...
# BMP7       BMP7 (Bone Morphogenetic Protein 7) is a Prote...
# MAFF       MAFF (MAF BZIP Transcription Factor F) is a Pr...
#
#                                         UniProtKB/Swiss-Prot  \
# CFAP74     As part of the central apparatus of the cilium...
# PRDM16-DT                                                NaN
# AGMAT                                                    NaN
# MACF1      [Isoform 2]: F-actin-binding protein which pla...
# NFIA       Recognizes and binds the palindromic sequence ...
# ...                                                      ...
# TOP1       Releases the supercoiling and torsional tensio...
# EYA2       Functions both as protein phosphatase and as t...
# TSHZ2      Probable transcriptional regulator involved in...
# BMP7       Growth factor of the TGF-beta superfamily that...
# MAFF       Since they lack a putative transactivation dom...
#
#                                                       Tocris CIViC
# CFAP74                                                   NaN   NaN
# PRDM16-DT                                                NaN   NaN
# AGMAT                                                    NaN   NaN
# MACF1                                                    NaN   NaN
# NFIA                                                     NaN   NaN
# ...                                                      ...   ...
# TOP1       Topoisomerases are ubiquitously expressed enzy...   NaN
# EYA2                                                     NaN   NaN
# TSHZ2                                                    NaN   NaN
# BMP7                                                     NaN   NaN
# MAFF                                                     NaN   NaN
#
# [149 rows x 6 columns]

# %%
summary_data.index.name = 'Gene'
summary_data.reset_index(inplace=True)

# %%
summary_data
# Out:
#           Gene                                        Description  \
# 0       CFAP74    Gene - Cilia And Flagella Associated Protein 74
# 1    PRDM16-DT                 Gene - PRDM16 Divergent Transcript
# 2        AGMAT                                  Gene - Agmatinase
# 3        MACF1     Gene - Microtubule Actin Crosslinking Factor 1
# 4         NFIA                          Gene - Nuclear Factor I A
# ..         ...                                                ...
# 144       TOP1                         Gene - DNA Topoisomerase I
# 145       EYA2  Gene - EYA Transcriptional Coactivator And Pho...
# 146      TSHZ2             Gene - Teashirt Zinc Finger Homeobox 2
# 147       BMP7                Gene - Bone Morphogenetic Protein 7
# 148       MAFF             Gene - MAF BZIP Transcription Factor F
#
#                                            Entrez Gene  \
# 0    Predicted to be involved in axoneme assembly. ...
# 1                                                  NaN
# 2    Predicted to enable agmatinase activity. Predi...
# 3    This gene encodes a large protein containing n...
# 4    This gene encodes a member of the NF1 (nuclear...
# ..                                                 ...
# 144  This gene encodes a DNA topoisomerase, an enzy...
# 145  This gene encodes a member of the eyes absent ...
# 146  This gene is a member of the teashirt C2H2-typ...
# 147  This gene encodes a secreted ligand of the TGF...
# 148  The protein encoded by this gene is a basic le...
#
#                                              GeneCards  \
# 0    CFAP74 (Cilia And Flagella Associated Protein ...
# 1    PRDM16-DT (PRDM16 Divergent Transcript) is an ...
# 2    AGMAT (Agmatinase) is a Protein Coding gene. D...
# 3    MACF1 (Microtubule Actin Crosslinking Factor 1...
# 4    NFIA (Nuclear Factor I A) is a Protein Coding ...
# ..                                                 ...
# 144  TOP1 (DNA Topoisomerase I) is a Protein Coding...
# 145  EYA2 (EYA Transcriptional Coactivator And Phos...
# 146  TSHZ2 (Teashirt Zinc Finger Homeobox 2) is a P...
# 147  BMP7 (Bone Morphogenetic Protein 7) is a Prote...
# 148  MAFF (MAF BZIP Transcription Factor F) is a Pr...
#
#                                   UniProtKB/Swiss-Prot  \
# 0    As part of the central apparatus of the cilium...
# 1                                                  NaN
# 2                                                  NaN
# 3    [Isoform 2]: F-actin-binding protein which pla...
# 4    Recognizes and binds the palindromic sequence ...
# ..                                                 ...
# 144  Releases the supercoiling and torsional tensio...
# 145  Functions both as protein phosphatase and as t...
# 146  Probable transcriptional regulator involved in...
# 147  Growth factor of the TGF-beta superfamily that...
# 148  Since they lack a putative transactivation dom...
#
#                                                 Tocris CIViC
# 0                                                  NaN   NaN
# 1                                                  NaN   NaN
# 2                                                  NaN   NaN
# 3                                                  NaN   NaN
# 4                                                  NaN   NaN
# ..                                                 ...   ...
# 144  Topoisomerases are ubiquitously expressed enzy...   NaN
# 145                                                NaN   NaN
# 146                                                NaN   NaN
# 147                                                NaN   NaN
# 148                                                NaN   NaN
#
# [149 rows x 7 columns]

# %%
summary_data.to_csv("../../data/output/genes_list.csv",index=False)
